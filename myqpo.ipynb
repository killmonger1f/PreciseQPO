# %%
import pandas as pd
import numpy as np

# %%
dcp=pd.read_csv("data/dailyClosingPrices.csv")

# %%
dcp
# Out:
#             Date        MSFT        AAPL         AMZN         GOOG  \
# 0     2013-01-02   23.074232   17.010899   257.309998   360.274597
# 1     2013-01-03   22.765125   16.796177   258.480011   360.483826
# 2     2013-01-04   22.339064   16.328323   259.149994   367.607117
# 3     2013-01-07   22.297297   16.232281   268.459991   366.003143
# 4     2013-01-08   22.180330   16.275965   266.380005   365.280823
# ...          ...         ...         ...          ...          ...
# 2132  2021-06-22  265.510010  133.979996  3505.439941  2539.989990
# 2133  2021-06-23  265.269989  133.699997  3503.820068  2529.229980
# 2134  2021-06-24  266.690002  133.410004  3449.080078  2545.639893
# 2135  2021-06-25  265.019989  133.110001  3401.459961  2539.899902
# 2136  2021-06-28  268.720001  134.779999  3443.889893  2536.389893
#
#               FB        TSLA        GOOGL        NVDA      CMCSA  ...  \
# 0      28.000000    7.072000   361.987000   11.763624  16.523232  ...
# ...

# %%
dcp_msft=dcp['MSFT']
dcp_msft
# Out:
# 0        23.074232
# 1        22.765125
# 2        22.339064
# 3        22.297297
# 4        22.180330
#            ...
# 2132    265.510010
# 2133    265.269989
# 2134    266.690002
# 2135    265.019989
# 2136    268.720001
# Name: MSFT, Length: 2137, dtype: float64

# %%
dcp_msft_open=dcp_msft[:-1].to_numpy()
dcp_msft_close=dcp_msft[1:].to_numpy()

# %%
dcp_msft_open
# Out:
# array([ 23.0742321 ,  22.76512527,  22.33906364, ..., 265.26998901,
#        266.69000244, 265.01998901])

# %%
dcp_msft_close
# Out:
# array([ 22.76512527,  22.33906364,  22.29729652, ..., 266.69000244,
#        265.01998901, 268.72000122])

# %%
dcp_msft_return=(dcp_msft_close-dcp_msft_open)/(dcp_msft_open)
dcp_msft_return
# Out:
# array([1.79457941e-04, 3.50271466e-04, 3.49574010e-06, ...,
#        2.86555444e-05, 3.92126737e-05, 1.94916700e-04])

# %%
dcp_msft_return.sum()
# Out:
# 0.5882817542140958
